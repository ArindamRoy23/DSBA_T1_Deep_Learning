# %% [markdown]
# $\mathbf{\text{Foundations of Deep Learning:  Assignment 2}}$ \\
#
# **Team:** \
# B00798800 - Arindam Roy \
# B00804388 - Pallav SAHU

# %% [markdown]
# # Importing Useful Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as T
import torchvision
import torch.nn.functional as F
from torch.autograd import Variable


from PIL import Image
import cv2
import albumentations as A

import time
import os
from tqdm.notebook import tqdm

# !pip install -q torcheval
from torcheval.metrics.functional import multiclass_f1_score

# !pip install -q segmentation-models-pytorch
# !pip install -q torchsummary

from torchsummary import summary
import segmentation_models_pytorch as smp

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 KB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 KB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 23.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 20.7 MB/s eta 0:00:00
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device
# Out:
# device(type='cuda')

# %%
# mounting drive to access files
from google.colab import drive

drive = drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# create a directory for saving the models and the training progress
save_folder = 'drive/MyDrive/FDL/FDL_project2/model_try9_gpu_psp'

# %%
##function which saves the overall accuracy and average loss at the end of each epoch,
##both for the training and the validation set
def write_results(save_folder, epoch, train_acc, val_acc, train_loss, val_loss):
    with open('./{}/progress.txt'.format(save_folder),'a') as ff:
      ff.write(' E: ')
      ff.write(str(epoch))
      ff.write('         ')
      ff.write(' TRAIN_OA: ')
      ff.write(str('%.3f' % train_acc))
      ff.write(' VAL_OA: ')
      ff.write(str('%.3f' % val_acc))
      ff.write('         ')
      ff.write(' TRAIN_IOU_LOSS: ')
      ff.write(str('%.3f' % train_loss))
      ff.write(' VAL_IOU_LOSS: ')
      ff.write(str('%.3f' % val_loss))
      ff.write('\n')

# %% [markdown]
# #Importing images + mask & Preprocessing

# %%
! mkdir Hurricane_Harvey
! mkdir Hurricane_Harvey/rasters Hurricane_Harvey/vectors
! gsutil -m cp -n -r gs://geoengine-dataset-houston-uav/rasters/raw Hurricane_Harvey/rasters/
! gsutil -m cp -n -r gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/ Hurricane_Harvey/vectors/
# Out:
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10170.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10171.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10172.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10174.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10300.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10184.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10566.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10808.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10810.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10812.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10814.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/10817.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6411.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6412.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6413.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6414.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6416.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6419.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6420.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6421.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6422.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6424.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6426.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6427.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6431.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6433.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6435.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6437.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6443.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6444.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6445.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6447.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6449.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6450.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6452.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6455.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6454.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6456.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6457.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6459.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6462.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6463.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6465.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6466.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6467.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6468.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6469.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6476.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6481.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6492.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6496.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6499.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6504.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6545.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6546.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6548.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6555.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6550.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6556.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6559.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6560.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6567.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6564.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6565.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6569.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6574.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6580.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6594.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6603.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6608.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6619.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6622.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6625.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6627.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6639.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6640.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6643.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6644.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6645.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6648.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6649.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6652.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6654.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6657.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6656.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6659.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6662.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6664.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6666.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6677.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6691.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6692.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6693.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6695.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6701.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6703.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6704.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6706.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6707.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6708.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6710.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6712.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6714.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6715.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6716.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6717.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6794.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6795.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6796.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6799.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6802.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6807.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6804.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6814.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6820.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6824.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6827.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6829.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6836.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6843.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6846.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6844.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6853.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6854.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6855.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6858.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6856.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6891.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6893.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6895.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6900.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6901.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6904.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6905.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6908.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6906.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6930.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6933.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6935.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6939.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6946.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6957.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6959.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6963.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6965.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6966.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6967.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6969.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6970.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6974.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6976.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6979.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6981.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6982.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6985.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6994.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/6996.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7004.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7009.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7147.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7151.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7042.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7156.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7192.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7193.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7194.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7232.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7233.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7235.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7236.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7238.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7239.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7241.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7245.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7243.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7251.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7252.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7253.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7256.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7257.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7258.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7261.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7263.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7264.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7265.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7270.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7272.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7278.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7285.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7290.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7294.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7298.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7300.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7301.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7304.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7305.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7306.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7308.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7310.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7311.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7313.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7314.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7315.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7316.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7318.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7320.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7321.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7322.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7323.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7324.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7328.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7330.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7332.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7335.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7336.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7339.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7356.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7362.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7366.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7370.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7372.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7374.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7406.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7410.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7412.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7414.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7415.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7422.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7426.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7427.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7429.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7431.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7434.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7438.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7457.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7463.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7465.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7466.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7467.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7469.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7473.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7481.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7485.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7488.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7477.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7489.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7520.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7521.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7525.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7526.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7541.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7542.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7552.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7556.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7559.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7560.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7567.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7571.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7573.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7575.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7579.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7580.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7582.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7581.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7583.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7584.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7586.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7590.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7593.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7595.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7596.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7597.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7601.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7605.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7606.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7609.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7611.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7614.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7616.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7641.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7650.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7673.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7677.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7682.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7685.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7690.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7691.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7719.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7720.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7721.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7751.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7787.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7788.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7829.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7859.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/7899.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8351.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8361.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8362.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8367.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8368.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8372.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8389.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8398.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8401.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8431.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8440.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8447.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8464.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8475.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8445.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8514.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8516.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8526.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8774.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8777.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8786.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8791.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8814.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8816.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8817.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8818.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8821.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8833.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8860.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8879.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8898.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8900.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8902.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8906.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8909.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8911.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8917.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8928.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8937.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8945.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8947.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8955.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8960.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8962.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9006.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/8966.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9034.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9036.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9039.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9042.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9044.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9045.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9055.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9064.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9068.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9070.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9079.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9080.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9082.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9083.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9084.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9087.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9091.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9094.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9099.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9101.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9103.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9106.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9107.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9108.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9110.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9367.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9459.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9722.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9723.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9725.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9795.tif...
# Copying gs://geoengine-dataset-houston-uav/rasters/raw/9925.tif...
# / [374/374 files][616.5 MiB/616.5 MiB] 100% Done  22.5 MiB/s ETA 00:00:00
# Operation completed over 374 objects/616.5 MiB.
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99acf.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad0.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad1.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad4.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad2.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad3.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad5.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad6.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad7.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad8.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ada.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ad9.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99adb.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99adc.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99add.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ade.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99adf.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae0.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae1.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae2.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae3.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae4.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae5.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae6.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae7.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae8.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99ae9.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aea.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aeb.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aec.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aed.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aef.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aee.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af0.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af1.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af2.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af3.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af4.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af5.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af6.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af7.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af8.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99af9.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99afa.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99afb.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99afc.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99afd.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99afe.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99aff.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b00.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b01.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b02.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b03.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b04.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b05.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b06.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b07.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b08.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b09.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b0a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b0b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b0c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b0e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b0d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b0f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b11.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b10.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b12.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b13.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b14.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b16.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b15.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b17.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b18.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b19.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b1a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b1b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b1d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b1c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b1e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b1f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b20.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b22.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b21.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b23.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b24.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b25.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b26.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b27.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b28.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b29.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b2a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b2b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b2c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b2d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b2e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b2f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b30.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b31.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b32.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b33.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b34.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b35.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b36.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b37.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b38.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b39.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b3a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b3b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b3c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b3d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b3e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b3f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b40.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b41.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b42.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b43.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b44.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b45.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b47.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b46.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b48.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b49.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b4a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b4b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b4c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b4d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b4e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b4f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b50.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b51.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b54.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b52.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b55.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b56.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b53.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b57.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b58.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b59.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b5a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b5b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b5c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b5d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b5e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b5f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b60.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b61.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b62.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b63.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b64.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b65.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b66.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b67.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b68.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b69.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b6a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b6b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b6c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b6d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b6e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b6f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b70.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b71.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b72.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b73.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b74.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b75.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b76.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b77.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b78.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b79.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b7a.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b7b.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b7c.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b7d.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b7e.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b7f.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b80.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b81.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b82.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b83.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b84.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b85.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b86.json...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/COCO/6373eb4cbfe85a8192f99b87.json...
# ...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7257.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7261.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7263.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7264.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7265.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7270.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7272.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7278.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7285.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7290.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7294.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7304.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7308.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7300.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7311.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7313.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7314.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7316.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7321.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7322.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7323.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7324.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7328.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7330.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7332.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7335.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7339.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7356.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7362.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7366.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7370.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7372.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7374.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7406.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7410.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7412.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7414.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7422.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7426.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7427.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7431.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7434.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7438.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7457.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7463.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7465.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7466.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7467.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7469.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7477.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7481.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7485.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7488.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7520.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7521.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7541.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7542.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7552.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7556.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7559.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7560.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7571.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7573.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7575.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7580.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7579.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7581.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7582.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7583.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7584.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7586.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7593.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7595.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7601.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7605.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7606.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7611.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7614.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7641.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7673.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7677.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7682.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7685.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7690.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7719.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7720.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7721.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7788.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7787.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7829.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/7859.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8351.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8361.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8367.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8368.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8372.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8389.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8398.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8401.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8440.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8445.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8464.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8475.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8514.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8516.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8526.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8774.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8791.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8816.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8814.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8817.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8818.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8833.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8879.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8898.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8900.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8902.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8906.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8911.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8909.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8917.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8928.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8937.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8945.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8947.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8960.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8962.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/8966.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9034.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9006.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9039.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9042.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9044.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9064.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9068.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9070.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9083.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9084.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9087.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9091.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9094.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9099.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9106.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9101.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9108.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9107.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9110.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9367.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9459.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9722.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9723.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9725.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/Masks/9925.png...
# Copying gs://geoengine-dataset-houston-uav/vectors/random-split-_2022_11_17-22_35_45/metadata.json...
# / [678/678 files][ 74.6 MiB/ 74.6 MiB] 100% Done   3.8 MiB/s ETA 00:00:00
# Operation completed over 678 objects/74.6 MiB.

# %%
# Defining the path variables for the image rasters and segmentation masks

IMAGE_PATH = '/content/Hurricane_Harvey/rasters/raw/'
MASK_PATH = '/content/Hurricane_Harvey/vectors/random-split-_2022_11_17-22_35_45/Masks/'

# %%
# n_classes = 27 as [0,26] labels

'''
Here we created a function "create_df" which outputs the indices of the training and testing images + mask based on the
availability of the mask in the imported dataset
'''

def create_df():
    train_set = []
    for dirname, _, filenames in os.walk(MASK_PATH):
      for filename in filenames:
          train_set.append(filename.split('.')[0])
    # print(train_set)
    name = []
    name_test_final = []
    
    for dirname, _, filenames in os.walk(IMAGE_PATH):
        for filename in filenames:
          if filename.split('.')[0] in train_set:
            name.append(filename.split('.')[0])
          else:
             name_test_final.append(filename.split('.')[0])
            # print(filename.split('.')[0])
    
    return (pd.DataFrame({'id': name}, index = np.arange(0, len(name))),\
            pd.DataFrame({'id': name_test_final}, index = np.arange(0, len(name_test_final))))

# %%
# Verifying that number of overall training images are 299 as mentioned on the challenge description
df = create_df()[0]
print('Total Images: ', len(df))
# Out:
# Total Images:  299

# %%
# Defining test and train index dataframes
train_df = create_df()[0]
test_df = create_df()[1]

# %%
#split overall train data into further train(90%) and validation (10%) sets to overcome and keep a check on overfitting

X_train, X_val = train_test_split(df['id'].values, test_size=0.1, random_state=42)

print('Train Size   : ', len(X_train))
print('Val Size     : ', len(X_val))
# Out:
# Train Size   :  269
# Val Size     :  30

# %% [markdown]
# # Verfiying and Visualizing imported images + masks

# %%
# taking an image and visualizing the shape of its resolution which is very high 
imagesss = cv2.imread(IMAGE_PATH + df['id'][50] + '.tif')
imagesss.shape
# Out:
# (3000, 4000, 3)

# %%
# taking a mask and visualizing the shape of its resolution which is very high
masksss = cv2.imread(MASK_PATH + df['id'][50] + '.png', cv2.IMREAD_GRAYSCALE)
masksss.shape
# Out:
# (3000, 4000)

# %%
# taking an image and the corresponding mask to visualizing the data side-by-side

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10))
ax1.imshow(imagesss)
ax1.set_title('Picture');

ax2.imshow(masksss)
ax2.set_title('Ground truth')
ax2.set_axis_off()

# %%
# taking an image and the corresponding mask to visualizing the data stacked over each other

plt.imshow(imagesss)
plt.imshow(masksss, alpha=0.6)
plt.title('Picture with Mask Appplied')
plt.show()

# %%
# Trying out the resizing of the image before creating class definitions

img = cv2.imread(IMAGE_PATH + df['id'][50] + '.tif')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
mask = cv2.imread(MASK_PATH + df['id'][50] + '.png', cv2.IMREAD_GRAYSCALE)

# Crop the center of the image
img = np.asarray(img)
mask = np.asarray(mask)

# Define the target size for image and mask
target_height = 512
target_width = 512
target_width_mask = 512

target_size = (target_height, target_width)
target_size_mask = (target_height, target_width_mask)

# Resize the image
'''
For 'RGB IMAGE' we have used "interpolation = cv2.INTER_LINEAR_EXACT" which uses the bilinear interpolation algorithm. 
This does the interpolation in two dimensions and predicts the function used to calculate the color of a pixel.
This algorithm is effective in handling visual distortions while zooming or enlarging an image.

For 'GRAYSCALE MASKS' we have used "interpolation = cv2.INTER_NEAREST_EXACT" which uses the nearest neighbor interpolation algorithm.
It retains the sharpness of the edges though the overall image may be blurred.

'''
img = cv2.resize(img, target_size, interpolation = cv2.INTER_LINEAR_EXACT) 
mask = cv2.resize(mask, target_size_mask, interpolation = cv2.INTER_NEAREST_EXACT)

plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.title('Picture with Mask Appplied')
plt.show()

# %% [markdown]
# # Creating Dataloaders and CNN compatible classes

# %% [markdown]
# ## Normalization of images
# Trying to find a mean and standard deviaion of train images for normalizing across the RGB channels

# %%
# class loadImg(Dataset):
    
#     def __init__(self, img_path, mask_path, X):
#         self.img_path = img_path
#         self.mask_path = mask_path
#         self.X = X
        
#     def __len__(self):
#         return len(self.X)
    
#     def __getitem__(self, idx):
#         img = cv2.imread(self.img_path + self.X[idx] + '.tif')
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)
        
#         img = Image.fromarray(img)
#         t = T.Compose([T.ToTensor()])
#         img = t(img)

#         mask = torch.from_numpy(mask).long()

#         return img, mask

# %%
# train_set = loadImg(IMAGE_PATH, MASK_PATH, X_train)

# %%
# # Compute the mean and std of the dataset, which is roughly consistent for training images

# mean = torch.zeros(3)
# std = torch.zeros(3)

# for image, label in train_set:
#     for i in range(3):
#         mean[i] += image[i,:,:].mean()
#         std[i] += image[i,:,:].std()

# mean /= len(train_set)
# std /= len(train_set)

# print(f"Mean values: {mean}")
# print(f"Standard deviation values: {std}")

# %%
# storing values for future use

mean_store = [0.4416, 0.4683, 0.3926]
std_store = [0.1777, 0.1602, 0.1885]

# %% [markdown]
# ## Balancing the Un-balanced Dataset
# Trying to find the weights to be applied to the loss criterion parameter "weights" so as to adjust for class imbalance present in the images and masks

# %%
# run carefully, takes around 20-30 minutes to run

# Weight calculation for classes

# Create an empty dictionary to store the class counts
# class_counts = {i: 0 for i in range(27)}

# # Iterate over the dataset to count the number of occurrences of each class
# for _, mask in train_set:
#     # convert mask tensor to numpy array
#     mask = mask.numpy()
#     # Flatten the mask to 1D array
#     mask = mask.ravel()
#     # convert to tensor
#     mask = torch.from_numpy(mask)
#     # use torch.unique() to count the number of occurrences of each class
#     class_id, class_counts_val = torch.unique(mask, return_counts=True)

#     # print(class_id,class_counts_val)

#     # store the result in the dictionary
#     for i in range(len(class_id)):
#         class_counts[int(class_id[i])] += int(class_counts_val[i])

# print(class_counts)
# Out:
# {0: 270291342, 1: 301769953, 2: 7617711, 3: 12718304, 4: 4913813, 5: 850145540, 6: 355094985, 7: 380403, 8: 1862821, 9: 131350, 10: 1102058, 11: 39107, 12: 431726, 13: 785933, 14: 125930910, 15: 3549129, 16: 25713353, 17: 326484, 18: 601397, 19: 30265762, 20: 1193530, 21: 3257370, 22: 192485515, 23: 127304418, 24: 494962228, 25: 27667, 26: 45281383}

# %%
# # calculate the total number of pixels in the masks
# total_pixels = sum(class_counts.values())

# # calculate the weight for each class and cap at 

# weights = {class_id: ((total_pixels - count) / total_pixels) for class_id, count in class_counts.items()}
# # weights = {class_id: round(1/(count / total_pixels),4) for class_id, count in class_counts.items()}


# print(weights)

# # Create a weight tensor
# weights_tsr = torch.Tensor([weights[i] for i in range(27)])


# # normalizing the weight tensor
# # weights_tsr = torch.nn.functional.normalize(weights_tsr, p=-1)
# weights_tsr = weights_tsr / weights_tsr.sum()

# # checking for value of sum of weight tsr
# print(weights_tsr.sum())
# print(weights_tsr)
# Out:
# {0: 0.9054324970530101, 1: 0.8944189972624409, 2: 0.9973347725379904, 3: 0.9955502154005336, 4: 0.9982807920449096, 5: 0.7025574690464176, 6: 0.8757620359129046, 7: 0.9998669074578662, 8: 0.9993482501914278, 9: 0.9999540442493637, 10: 0.9996144202311787, 11: 0.999986317536809, 12: 0.9998489509524234, 13: 0.9997250236698532, 14: 0.9559402398374192, 15: 0.9987582574244397, 16: 0.9910036053407716, 17: 0.9998857722322747, 18: 0.9997895877383678, 19: 0.9894108427005113, 20: 0.9995824166954178, 21: 0.9988603358701943, 22: 0.932654614933928, 23: 0.9554596871830995, 24: 0.8268263363203151, 25: 0.999990320078014, 26: 0.9841572900981184}
# tensor(1.0000)
# tensor([0.0348, 0.0344, 0.0384, 0.0383, 0.0384, 0.0270, 0.0337, 0.0385, 0.0384,
#         0.0385, 0.0384, 0.0385, 0.0385, 0.0385, 0.0368, 0.0384, 0.0381, 0.0385,
#         0.0385, 0.0381, 0.0384, 0.0384, 0.0359, 0.0367, 0.0318, 0.0385, 0.0379])

# %%
# Storing the weight tensor for future use, which is roughly consistent for training images
weights_tsr = torch.tensor([0.0348, 0.0344, 0.0384, 0.0383, 0.0384, 0.0270, 0.0337, 0.0385, 0.0384,
        0.0385, 0.0384, 0.0385, 0.0385, 0.0385, 0.0368, 0.0384, 0.0381, 0.0385,
        0.0385, 0.0381, 0.0384, 0.0384, 0.0359, 0.0367, 0.0318, 0.0385, 0.0379])

# %% [markdown]
# # Neural Network Model Architecture (WIP)
# As the task is to input an RGB image (3 channels x W x H ) and predict a semantic segmentation mask for the 26 classes + 1 background class, we have leveraged various "pre-trained encoder-decoder architectures", which at an overall level, first learn the features by convolution and then bring back the features to required segmented polygons as the logits and the number of output class labels using up-convolution/ transpose-convolution

# %%
# trying to use suggested preprocessing for the inputs fed into a particular backbone
from segmentation_models_pytorch.encoders import get_preprocessing_fn
preprocess_input = get_preprocessing_fn('resnet101', pretrained='imagenet')

# %%
model = smp.DeepLabV3Plus(encoder_name='resnet101', encoder_weights='imagenet', classes=27, activation=None)

# %%
# model = smp.FPN('resnet152', encoder_weights='imagenet', encoder_depth=5, classes=27, decoder_segmentation_channels=256,activation=None)

# %%
# model = smp.Unet('resnet101', encoder_weights='imagenet', classes=27, decoder_use_batchnorm =True, 
#                  activation=None, encoder_depth=5, decoder_channels=[256, 128, 64, 32, 16]
#                  )

# %%
# model = smp.PSPNet(encoder_name='resnet152', encoder_weights='imagenet', classes=27, activation=None)

# %%
# printing model layers
model

# %% [markdown]
# # Creating Dataloaders and Model architecture compatible classes

# %% [markdown]
# ## Dataloader class description
#
# The provided code defines a custom dataset class called DroneDataset that inherits from the PyTorch Dataset class. This class is used to load, preprocess, and return images and masks for training and testing a model.
#
#
# ---
#
#
# The __init__ method of the class takes several arguments:
#
# 1. img_path: a string representing the path to the directory containing the images.
#
# 2. mask_path: a string representing the path to the directory containing the masks.
#
# 3. X: a list of strings representing the indices of the images (without the file extension).
#
# 4. mean: a tuple representing the mean values of the image channels.
#
# 5. std: a tuple representing the standard deviation values of the image channels.
#
# 6. transform: a transform object from albumentations library to apply data
# augmentation.
#
# 7. patch: a boolean flag indicating whether the images should be divided into patches.
#
#
#
# ---
#
#
# The __len__ method returns the length of the dataset, which is the number of images.
#
#
# ---
#
#
# The __getitem__ method takes an index, idx, as an input and returns the idx-th image and its corresponding mask. The method reads the image and mask from the specified paths, converts it from BGR to RGB, resizes the image and mask to a fixed size of 512x512 while preserving the aspect ratio. Then it applies the data augmentation using the albumentations library if the transform is not None. After that, it applies normalization to the image using the provided mean and standard deviation, and converts the image to a PyTorch tensor. The mask is converted to a PyTorch tensor of type long.
#
#
# ---
#
#
#
# The __tiles__ method is used to divide the image and mask into smaller patches of size 512x512. It uses the PyTorch's unfold method to divide the image and mask into overlapping patches of the desired size. Then it reshapes the patches to have the desired dimensions.

# %%
class DroneDataset(Dataset):
    
    def __init__(self, img_path, mask_path, X, mean, std, transform=None, patch=False):
        self.img_path = img_path
        self.mask_path = mask_path
        self.X = X
        self.transform = transform
        self.patches = patch
        self.mean = mean
        self.std = std
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.tif')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)

        img = np.asarray(img)
        mask = np.asarray(mask)

        # Define the target size
        target_height = 512
        target_width = 512
        target_width_mask = 512

        target_size = (target_height, target_width)
        target_size_mask = (target_height, target_width_mask)

        # Resize the image
        img = cv2.resize(img, target_size, interpolation = cv2.INTER_LINEAR_EXACT)
        mask = cv2.resize(mask, target_size_mask, interpolation = cv2.INTER_NEAREST_EXACT)
        
        if self.transform is not None:
            aug = self.transform(image=img, mask=mask)
            img = Image.fromarray(aug['image'])
            mask = aug['mask']
        
        if self.transform is None:
            img = Image.fromarray(img)
        
        t = T.Compose([T.ToTensor(), T.Normalize(self.mean, self.std)])
        img = t(img)

        mask = torch.from_numpy(mask).long()

        
        if self.patches:
            img, mask = self.tiles(img, mask)
            
        return img, mask
    
    def tiles(self, img, mask):
       
        # change n_s1 as you change the image shape dimensions
        n_sq = 512
        # aspect_ratio = img.shape[1]/img.shape[0]
        aspect_ratio = 1

        img_patches = img.unfold(1, n_sq, n_sq).unfold(2, (n_sq/aspect_ratio), (n_sq/aspect_ratio)) 
        img_patches  = img_patches.contiguous().view(3,-1, (n_sq/aspect_ratio), (n_sq/aspect_ratio)) 
        img_patches = img_patches.permute(1,0,2,3)
        
        mask_patches = mask.unfold(0, n_sq, n_sq).unfold(1, (n_sq/aspect_ratio), (n_sq/aspect_ratio))
        mask_patches = mask_patches.contiguous().view(-1, (n_sq/aspect_ratio), (n_sq/aspect_ratio))
        
        return img_patches, mask_patches

# %%
# defining the input parameters for the DroneDataset

'''
RGB mean and std values calculated as before
'''
mean = [0.4416, 0.4683, 0.3926]
std = [0.1777, 0.1602, 0.1885]


'''
Transforms for train and validation images using "albumentations" module
'''
t_train = A.Compose([
                   A.OneOf(
                     [A.HorizontalFlip(), A.VerticalFlip(),  A.RandomBrightnessContrast((0,0.5),(0,0.5))],p=0.75,
                     )
                   ])

t_val = A.Compose([
                   A.OneOf(
                     [A.HorizontalFlip(), A.VerticalFlip(),  A.RandomBrightnessContrast((0,0.5),(0,0.5))],p=0.75,
                     )
                   ])


'''
Calling the "DroneDataset" class with desired inputs
'''
train_set = DroneDataset(IMAGE_PATH, MASK_PATH, X_train, mean, std, transform=t_train, patch=False)
val_set = DroneDataset(IMAGE_PATH, MASK_PATH, X_val, mean, std, transform=t_val, patch=False)


'''
Calling the Dataloader with desired batch sizes for training and validation
'''

batch_size= 10
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)

batch_size= 4
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Defining evaluation metrics
#
# 1. pixel_accuracy : to track per-pixel accuracy for each output label and averaged across classes to generate a single value
#
# 2. mIoU : to track Dice-coefficient or similarity of predicition set with the a specific mask label for each class and averaged across classes to generate a single value

# %%
def pixel_accuracy(output, mask):
    with torch.no_grad():
        output = torch.argmax(F.softmax(output, dim=1), dim=1)
        correct = torch.eq(output, mask).int()
        accuracy = float(correct.sum()) / float(correct.numel())
    return accuracy

# %%
def mIoU(pred_mask, mask, smooth=1e-10, n_classes=27):
    with torch.no_grad():
        pred_mask = F.softmax(pred_mask, dim=1)
        pred_mask = torch.argmax(pred_mask, dim=1)
        pred_mask = pred_mask.contiguous().view(-1)
        mask = mask.contiguous().view(-1)

        iou_per_class = []
        for clas in range(0, n_classes):
            true_class = pred_mask == clas
            true_label = mask == clas

            if true_label.long().sum().item() == 0:
                iou_per_class.append(np.nan)
            else:
                intersect = torch.logical_and(true_class, true_label).sum().float().item()
                union = torch.logical_or(true_class, true_label).sum().float().item()

                iou = 2*(intersect + smooth) / (union + intersect +smooth)
                iou_per_class.append(iou)
        return np.nanmean(iou_per_class)

# %% [markdown]
# ## Defining Model training routine and Learning rate scheduler

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit(epochs, model, train_loader, val_loader, criterion, optimizer, scheduler, patch=False):
    torch.cuda.empty_cache()
    train_losses = []
    test_losses = []
    val_iou = []; val_acc = []
    train_iou = []; train_acc = []
    lrs = []
    min_loss = np.inf
    decrease = 1 ; not_improve=0

    model.to(device)

    fit_time = time.time()
    for e in range(epochs):
        since = time.time()
        running_loss = 0
        iou_score = 0
        accuracy = 0
        #training loop
        model.train()
        for i, data in enumerate(tqdm(train_loader)):
            #training phase
            image_tiles, mask_tiles = data
            
            if patch:
                bs, n_tiles, c, h, w = image_tiles.size()

                image_tiles = image_tiles.view(-1, c, h, w)
                mask_tiles = mask_tiles.view(-1, h, w)
            
            image = image_tiles.to(device);
            mask = mask_tiles.to(device);

            #forward
            output = model(image)
            loss = criterion(output, mask)

            #evaluation metrics
            iou_score += mIoU(output, mask)
            accuracy += pixel_accuracy(output, mask)

            optimizer.zero_grad() #reset gradient

            #backward
            loss.backward()
            optimizer.step() #update weight          
            
            
            #step the learning rate
            lrs.append(get_lr(optimizer))
            scheduler.step() 
            
            running_loss += loss.item()

            torch.save({'epoch': e, 'model_state_dict': model.state_dict(),
                        'optimizer_state_dict': optimizer.state_dict()},save_folder + '/model_{}.pt'.format(e))
            
        else:
            model.eval()
            test_loss = 0
            test_accuracy = 0
            val_iou_score = 0
            #validation loop
            with torch.no_grad():
                for i, data in enumerate(tqdm(val_loader)):
                    #reshape to 9 patches from single image, delete batch size
                    image_tiles, mask_tiles = data

                    if patch:
                        bs, n_tiles, c, h, w = image_tiles.size()

                        image_tiles = image_tiles.view(-1, c, h, w)
                        mask_tiles = mask_tiles.view(-1, h, w)
                    
                    image = image_tiles.to(device); 
                    mask = mask_tiles.to(device);

                    output = model(image)
                    #evaluation metrics
                    val_iou_score +=  mIoU(output, mask)
                    test_accuracy += pixel_accuracy(output, mask)

                    #loss
                    loss = criterion(output, mask)                                  
                    test_loss += loss.item()
                    
            
            #calculation mean for each batch
            train_losses.append(running_loss/len(train_loader))
            test_losses.append(test_loss/len(val_loader))


            if min_loss > (test_loss/len(val_loader)):
                print('Loss Decreasing.. {:.3f} >> {:.3f} '.format(min_loss, (test_loss/len(val_loader))))
                min_loss = (test_loss/len(val_loader))
                decrease += 1
                if decrease % 5 == 0:
                    print('saving model...')
                    torch.save(model, 'Unet-Mobilenet_v2_mIoU-{:.3f}.pt'.format(val_iou_score/len(val_loader)))
                    

            if (test_loss/len(val_loader)) > min_loss:
                not_improve += 1
                min_loss = (test_loss/len(val_loader))
                print(f'Loss Not Decrease for {not_improve} time')
                if not_improve == 7:
                    print('Loss not decrease for 7 times, Stop Training')
                    break
            
            #iou
            val_iou.append(val_iou_score/len(val_loader))
            train_iou.append(iou_score/len(train_loader))
            train_acc.append(accuracy/len(train_loader))
            val_acc.append(test_accuracy/ len(val_loader))

            write_results(save_folder, e, (accuracy/len(train_loader)), (test_accuracy/ len(val_loader)), (iou_score/len(train_loader)), (val_iou_score/len(val_loader)))

            print("Epoch:{}/{}..".format(e+1, epochs),
                  "Train Loss: {:.3f}..".format(running_loss/len(train_loader)),
                  "Val Loss: {:.3f}..".format(test_loss/len(val_loader)),
                  "Train mIoU:{:.3f}..".format(iou_score/len(train_loader)),
                  "Val mIoU: {:.3f}..".format(val_iou_score/len(val_loader)),
                  "Train Acc:{:.3f}..".format(accuracy/len(train_loader)),
                  "Val Acc:{:.3f}..".format(test_accuracy/len(val_loader)),
                  "Time: {:.2f}m".format((time.time()-since)/60)
                  )
            
        
    history = {'train_loss' : train_losses, 'val_loss': test_losses,
               'train_miou' :train_iou, 'val_miou':val_iou,
               'train_acc' :train_acc, 'val_acc':val_acc,
               'lrs': lrs}
    print('Total time: {:.2f} m' .format((time.time()- fit_time)/60))
    return history

# %% [markdown]
# ## Fitting the model to training images

# %%
# Parameters for training the model
max_lr = 1e-4
epoch = 25
weight_decay = 1e-4

# without using weights for the classes
criterion = nn.CrossEntropyLoss().to(device)
# using weights for the classes as calculated above 
# criterion = nn.CrossEntropyLoss(weight = weights_tsr.to(device)).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=max_lr, weight_decay=weight_decay)
sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epoch, steps_per_epoch=len(train_loader))

history = fit(epoch, model, train_loader, val_loader, criterion, optimizer, sched,patch=False)

# %% [markdown]
# ## Defining evaluation metric visualizations

# %%
def plot_loss(history):
    plt.plot(history['val_loss'], label='val', marker='o')
    plt.plot( history['train_loss'], label='train', marker='o')
    plt.title('Loss per epoch'); plt.ylabel('loss');
    plt.xlabel('epoch')
    plt.legend(), plt.grid()
    plt.show()
    
def plot_score(history):
    plt.plot(history['train_miou'], label='train_mIoU', marker='*')
    plt.plot(history['val_miou'], label='val_mIoU',  marker='*')
    plt.title('Score per epoch'); plt.ylabel('mean IoU')
    plt.xlabel('epoch')
    plt.legend(), plt.grid()
    plt.show()
    
def plot_acc(history):
    plt.plot(history['train_acc'], label='train_accuracy', marker='*')
    plt.plot(history['val_acc'], label='val_accuracy',  marker='*')
    plt.title('Accuracy per epoch'); plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(), plt.grid()
    plt.show()

# %%
plot_loss(history)
plot_score(history)
plot_acc(history)

# %% [markdown]
# # Model Validation and Mask Evaluation

# %% [markdown]
# ## Dataloader class for validation

# %%
class DroneTestDataset(Dataset):
    
    def __init__(self, img_path, mask_path, X, transform=None):
        self.img_path = img_path
        self.mask_path = mask_path
        self.X = X
        self.transform = transform
      
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.tif')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)

        img = np.asarray(img)
        mask = np.asarray(mask)

        # Define the target size
        target_height = 512
        target_width = 512
        target_width_mask = 512

        target_size = (target_height, target_width)
        target_size_mask = (target_height, target_width_mask)

        # Resize the image
        img = cv2.resize(img, target_size, interpolation = cv2.INTER_LINEAR_EXACT)
        mask = cv2.resize(mask, target_size_mask, interpolation = cv2.INTER_NEAREST_EXACT)

        
        if self.transform is not None:
            aug = self.transform(image=img, mask=mask)
            img = Image.fromarray(aug['image'])
            mask = aug['mask']
        
        if self.transform is None:
            img = Image.fromarray(img)
        
        mask = torch.from_numpy(mask).long()
        
        return img, mask

# %%
# calling on the validation set for validation test images and masks
test_set = DroneTestDataset(IMAGE_PATH, MASK_PATH, X_val, transform=None)

# %% [markdown]
# ## Loading best model
# On the basis of training anf validation losses, loading the model at an optimal epoch

# %%
# loading the best models from the saved folders
model_best = model.to(device);


if device == 'cuda':
  checkpoint = torch.load('/content/drive/MyDrive/FDL/FDL_project2/model_try9_gpu_psp/model_17.pt')
else:
  checkpoint = torch.load('/content/drive/MyDrive/FDL/FDL_project2/model_try9_gpu_psp/model_17.pt',map_location=torch.device('cpu'))


model_best.load_state_dict(checkpoint['model_state_dict'])

optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

current_epoch = checkpoint['epoch']

# %% [markdown]
# ## Defining mask evaluation functions
#
# 1. predict_image_mask_miou : compares the ground truth with predicted output labels per class to generate mIou/similarity/Dice-coefficient
#
# 2. predict_image_mask_pixel : compares the ground truth with predicted output labels per pixel to generate pixel accuracy

# %%
# mean_store = [0.4416, 0.4683, 0.3926]
# std_store = [0.1777, 0.1602, 0.1885]

def predict_image_mask_miou(model, image, mask, mean=[0.4416, 0.4683, 0.3926], std=[0.1777, 0.1602, 0.1885]):
    model.eval()
    t = T.Compose([T.ToTensor(), T.Normalize(mean, std)])
    image = t(image)

    model.to(device); image=image.to(device)

    mask = mask.to(device)
    with torch.no_grad():
        
        image = image.unsqueeze(0)
        mask = mask.unsqueeze(0)
        
        output = model(image)
        score = mIoU(output, mask)
        masked = torch.argmax(output, dim=1)
        masked = masked.cpu().squeeze(0)
    return masked, score

# %%
def predict_image_mask_pixel(model, image, mask, mean=[0.4416, 0.4683, 0.3926], std=[0.1777, 0.1602, 0.1885]):
    model.eval()
    t = T.Compose([T.ToTensor(), T.Normalize(mean, std)])
    image = t(image)

    model.to(device); image=image.to(device)

    mask = mask.to(device)
    with torch.no_grad():
        
        image = image.unsqueeze(0)
        mask = mask.unsqueeze(0)
        
        output = model(image)
        acc = pixel_accuracy(output, mask)
        masked = torch.argmax(output, dim=1)
        masked = masked.cpu().squeeze(0)
    return masked, acc

# %% [markdown]
# ## Calling the validation functions

# %%
image, mask = test_set[3]
pred_mask, score = predict_image_mask_miou(model_best, image, mask)

# %%
def miou_score(model, test_set):
    score_iou = []
    for i in tqdm(range(len(test_set))):
        img, mask = test_set[i]
        pred_mask, score = predict_image_mask_miou(model, img, mask)
        score_iou.append(score)
    return score_iou

# %%
mob_miou = miou_score(model_best, test_set)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
def pixel_acc(model, test_set):
    accuracy = []
    for i in tqdm(range(len(test_set))):
        img, mask = test_set[i]
        pred_mask, acc = predict_image_mask_pixel(model, img, mask)
        accuracy.append(acc)
    return accuracy

# %%
mob_acc = pixel_acc(model_best, test_set)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# ## Results by visualizing mask shapes and classes

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
ax1.imshow(image)
ax1.set_title('Picture');

ax2.imshow(mask)
ax2.set_title('Ground truth')
ax2.set_axis_off()

ax3.imshow(pred_mask)
ax3.set_title('UNet-MobileNet | mIoU {:.3f}'.format(score))
ax3.set_axis_off()

# %%
image2, mask2 = test_set[4]
pred_mask2, score2 = predict_image_mask_miou(model, image2, mask2)

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
ax1.imshow(image2)
ax1.set_title('Picture');

ax2.imshow(mask2)
ax2.set_title('Ground truth')
ax2.set_axis_off()

ax3.imshow(pred_mask2)
ax3.set_title('UNet-MobileNet | mIoU {:.3f}'.format(score2))
ax3.set_axis_off()

# %%
image3, mask3 = test_set[20]
pred_mask3, score3 = predict_image_mask_miou(model, image3, mask3)

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
ax1.imshow(image3)
ax1.set_title('Picture');

ax2.imshow(mask3)
ax2.set_title('Ground truth')
ax2.set_axis_off()

ax3.imshow(pred_mask3)
ax3.set_title('UNet-MobileNet | mIoU {:.3f}'.format(score3))
ax3.set_axis_off()

# %%
print('Test Set mIoU', np.mean(mob_miou))
# Out:
# Test Set mIoU 0.3470656192432669

# %%
print('Test Set Pixel Accuracy', np.mean(mob_acc))
# Out:
# Test Set Pixel Accuracy 0.725350193245701

# %% [markdown]
# # Output TAR files

# %%
# create mask for test 75 images -> resize as original image - > name it properly

# %% [markdown]
# ## Dataloader class for test and predictions

# %%
class DroneTestFinalDataset(Dataset):
    
    def __init__(self, img_path, X, transform=None):
        self.img_path = img_path
        self.X = X
        self.transform = transform
      
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.tif')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = np.asarray(img)

        # Define the target size
        target_height = 512
        target_width = 512
        
        target_size = (target_height, target_width)

        # Resize the image
        img = cv2.resize(img, target_size, interpolation = cv2.INTER_LINEAR_EXACT)

        
        if self.transform is not None:
            aug = self.transform(image=img)
            img = Image.fromarray(aug['image'])
        
        if self.transform is None:
            img = Image.fromarray(img)
        
        return img

# %%
test_df = create_df()[1]['id']

# %%
X_test_final = DroneTestFinalDataset(IMAGE_PATH, test_df, transform=None)

# %%
# verifying the length of final classes
len(X_test_final)
# Out:
# 75

# %%
# visualizing a test image
image = X_test_final[8]
plt.imshow(image)
print(np.asarray(image).shape)
# Out:
# (448, 576, 3)

# %% [markdown]
# ## Defining function for predicting final masks

# %%
def final_predict_mask(model, image, mean=[0.4416, 0.4683, 0.3926], std=[0.1777, 0.1602, 0.1885]):
    model.eval()
    t = T.Compose([T.ToTensor(), T.Normalize(mean, std)])
    image = t(image)

    model.to(device); 
    image=image.to(device)

    with torch.no_grad():
        
        image = image.unsqueeze(0)
        
        output = model(image)

        masked = torch.argmax(output, dim=1)
        masked = masked.cpu().squeeze(0)
    return image, masked

# %% [markdown]
# ## Visualizing the output mask and resized to original dimensions

# %%
n =8
image = X_test_final[n]
_, pred_mask = final_predict_mask(model, image)

fig, (ax1, ax2,ax3) = plt.subplots(1,3, figsize=(15,12))
ax1.imshow(image)
ax1.set_title('Picture');

ax2.imshow(pred_mask)
ax2.set_title('UNet-MobileNet | mask'.format(n))
ax2.set_axis_off()

target_size = (4000,3000)
mask_new = cv2.resize(np.asarray(pred_mask,dtype='uint8'), target_size, interpolation = cv2.INTER_NEAREST_EXACT)

ax3.imshow(mask_new)
ax3.set_title('UNet-MobileNet | mask_resized'.format(n))
ax3.set_axis_off()


print(test_df.iloc[n,])
print(mask_new.shape)
# Out:
# 9079
# (3000, 4000)

# %% [markdown]
# ## Uploading files to submission tar

# %%
# !rm -rf /content/Hurricane_Harvey/new/test_mask_dir

# %%
# !mkdir -p /content/Hurricane_Harvey/new/test_mask_dir
# %cd /content/Hurricane_Harvey/new/test_mask_dir
from google.colab import files
# Out:
# /content/Hurricane_Harvey/new/test_mask_dir

# %%
import os
from PIL import Image

# Create a new folder in Colab
# !mkdir /content/Hurricane_Harvey/new/test_mask_dir
# Out:
# mkdir: cannot create directory ‘/content/Hurricane_Harvey/new/test_mask_dir’: File exists

# %%
for i in range(test_df.shape[0]):
    img = Image.open(IMAGE_PATH + test_df.iloc[i,] + '.tif')
    image_model = X_test_final[i]

    final_width = np.asarray(img).shape[0]
    final_height = np.asarray(img).shape[1]

    _, pred_mask = final_predict_mask(model, image_model)

    target_size = (final_height,final_width)

    pred_mask_new = cv2.resize(np.asarray(pred_mask,dtype='uint8'), target_size, interpolation = cv2.INTER_NEAREST_EXACT)

    pred_mask_new = Image.fromarray(pred_mask_new).convert('L')
    

    # Save the image as a PNG file
    file_name = test_df.iloc[i,]+".png"
    file_path = "/content/Hurricane_Harvey/new/test_mask_dir/" + file_name
    pred_mask_new.save(file_path)

    print('Image Size:', np.asarray(img).shape, 'Pred Mask Size', np.asarray(pred_mask_new).shape)
# Out:
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3000, 4000, 3) Pred Mask Size (3000, 4000)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)
# Image Size: (3072, 4592, 3) Pred Mask Size (3072, 4592)

# %%
# code for generating a tar zip

import tarfile
num = 11
tar = tarfile.open("submission_"+str(num)+".tar", "w")

for root, dir, files in os.walk('/content/Hurricane_Harvey/new/test_mask_dir'):
    for  file in files:
        fullpath = os.path.join(root, file)
        tar.add(fullpath, arcname=file)

tar.close()
